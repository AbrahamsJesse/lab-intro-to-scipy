# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
#import numpy and pandas

# %% [markdown]
# # Challenge 1 - The `stats` Submodule
#
# This submodule contains statistical functions for conducting hypothesis tests, producing various distributions and other useful tools. Let's examine this submodule using the KickStarter dataset. Load the data using the `ks-projects-201801.csv` file

# %%
# Your code here:
import pandas as pd
project = pd.read_csv('ks-projects-201801.csv')
project
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %% [markdown]
# Now print the `head` function to examine the dataset.

# %%
# Your code here:

project.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %% [markdown]
# Import the `mode` function from `scipy.stats` and find the mode of the `country` and `currency` column.

# %%
# Your code here:
from scipy import stats #ESTE

stats.mode(project['country'])
# Out:
# /var/folders/5f/r18b_gks5397pfzpsrws6kqm0000gn/T/ipykernel_39471/4177756628.py:4: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(project['country'])
# /var/folders/5f/r18b_gks5397pfzpsrws6kqm0000gn/T/ipykernel_39471/4177756628.py:4: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   stats.mode(project['country'])
# ModeResult(mode=array(['US'], dtype=object), count=array([292627]))

# %%
stats.mode(project['currency'])
# Out:
# /var/folders/5f/r18b_gks5397pfzpsrws6kqm0000gn/T/ipykernel_39471/1519320804.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   stats.mode(project['currency'])
# /var/folders/5f/r18b_gks5397pfzpsrws6kqm0000gn/T/ipykernel_39471/1519320804.py:1: DeprecationWarning: Support for non-numeric arrays has been deprecated as of SciPy 1.9.0 and will be removed in 1.11.0. `pandas.DataFrame.mode` can be used instead, see https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html.
#   stats.mode(project['currency'])
# ModeResult(mode=array(['USD'], dtype=object), count=array([295365]))

# %% [markdown]
# The trimmed mean is a function that computes the mean of the data with observations removed. The most common way to compute a trimmed mean is by specifying a percentage and then removing elements from both ends. However, we can also specify a threshold on both ends. The goal of this function is to create a more robust method of computing the mean that is less influenced by outliers. SciPy contains a function called `tmean` for computing the trimmed mean.
#
# In the cell below, import the `tmean` function and then find the 75th percentile of the `goal` column. Compute the trimmed mean between 0 and the 75th percentile of the column. Read more about the `tmean` function [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.tmean.html#scipy.stats.tmean).

# %%
# Your code here:
from scipy import stats #ESTE
import numpy as np

percentile= project['goal']

# Calculate the 25th percentile (Q1)
q1 = np.percentile(percentile, 25)

# Calculate the 50th percentile (median or Q2)
q2 = np.percentile(percentile, 50)

# Calculate the 75th percentile (Q3)
q3 = np.percentile(percentile, 75)

print("Q1 (25th percentile):", q1)
print("Q2 (50th percentile):", q2)
print("Q3 (75th percentile):", q3)
# Out:
# Q1 (25th percentile): 2000.0
# Q2 (50th percentile): 5200.0
# Q3 (75th percentile): 16000.0

# %%
mean_trimmed = stats.trim_mean(percentile, proportiontocut=q3/100)
mean_trimmed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 mean_trimmed = stats.trim_mean(percentile, proportiontocut=q3/100)
#       2 mean_trimmed
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:3679, in trim_mean(a, proportiontocut, axis)
#    3677 uppercut = nobs - lowercut
#    3678 if (lowercut > uppercut):
# -> 3679     raise ValueError("Proportion too big.")
#    3681 atmp = np.partition(a, (lowercut, uppercut - 1), axis)
#    3683 sl = [slice(None)] * atmp.ndim
#
# ValueError: Proportion too big.

# %% [markdown]
# #### SciPy contains various statistical tests. One of the tests is Fisher's exact test. This test is used for contingency tables.
#
# The test originates from the "Lady Tasting Tea" experiment. In 1935, Fisher published the results of the experiment in his book. The experiment was based on a claim by Muriel Bristol that she can taste whether tea or milk was first poured into the cup. Fisher devised this test to disprove her claim. The null hypothesis is that the treatments do not affect outcomes, while the alternative hypothesis is that the treatment does affect outcome. To read more about Fisher's exact test, see:
#
# * [Wikipedia's explanation](http://b.link/test61)
# * [A cool deep explanation](http://b.link/handbook47)
# * [An explanation with some important Fisher's considerations](http://b.link/significance76)
#
# Let's perform Fisher's exact test on our KickStarter data. We intend to test the hypothesis that the choice of currency has an impact on meeting the pledge goal. We'll start by creating two derived columns in our dataframe. The first will contain 1 if the amount of money in `usd_pledged_real` is greater than the amount of money in `usd_goal_real`. We can compute this by using the `np.where` function. If the amount in one column is greater than the other, enter a value of 1, otherwise enter a value of zero. Add this column to the dataframe and name it `goal_met`.

# %%
import numpy as np
import pandas as pd
from scipy.stats import fisher_exact

# Create the 'goal_met' column using np.where
project['goal_met'] = np.where  (project['usd_pledged_real'] > project['usd_goal_real'], 1, 0)

project
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
project['goal_met'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Next, create a column that checks whether the currency of the project is in US Dollars. Create a column called `usd` using the `np.where` function where if the currency is US Dollars, assign a value of 1 to the row and 0 otherwise.

# %%
# Your code here:

project['usd'] = np.where  (project['currency']=='USD', 1, 0)

project
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %% [markdown]
# Now create a contingency table using the `pd.crosstab` function in the cell below to compare the `goal_met` and `usd` columns.

# %%
contingency_table = pd.crosstab(index=project['goal_met'], columns=project['usd'])

print(contingency_table)
# Out:
# usd           0       1
# goal_met
# 0         58685  187130
# 1         24611  108235

# %% [markdown]
# Import the `fisher_exact` function from `scipy.stats` and conduct the hypothesis test on the contingency table that you have generated above. You can read more about the `fisher_exact` function [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.fisher_exact.html#scipy.stats.fisher_exact). The output of the function should be the odds ratio and the p-value. The p-value will provide you with the outcome of the test.

# %%
from scipy.stats import fisher_exact

p_value = fisher_exact(contingency_table)
odds_ratio = fisher_exact(contingency_table)
# Display the results
print(f"Odds Ratio: {odds_ratio}")
print('')
print(f"P-value: {p_value}")
# Out:
# Odds Ratio: SignificanceResult(statistic=1.3791838163150314, pvalue=2.994e-320)
#
# P-value: SignificanceResult(statistic=1.3791838163150314, pvalue=2.994e-320)

# %% [markdown]
# # Challenge 2 - The `interpolate` submodule
#
# This submodule allows us to interpolate between two points and create a continuous distribution based on the observed data.
#
# In the cell below, import the `interp1d` function from `scipy.interpolate` and first take a sample of 10 rows from `kickstarter`.
#
# **Make sure there are not duplicated values in `backers`**

# %%
# Your code here:

import pandas as pd
from scipy.interpolate import interp1d


sample_df = project.sample(n=10, random_state=42)
sample_df = sample_df.drop_duplicates(subset=['backers'])

print("Sample DataFrame:")
print(sample_df)
# Out:
# Sample DataFrame:
#                 ID                                               name  \
# 113483  1576537356                                               Deko
# 315283   675907016  Westside BJ's: The Gluten-Free, Organic Food T...
# 254054   361890770                              Crepe Diem Food Truck
# 44306   1225211551  Season's End - A horror novel ready for public...
# 220478  2122944289        Colorado City Arizona Restaurant (Canceled)
# 79222   1403033985        Faces & Places In Brevard County (Canceled)
# 53451   1272109539  KiDCASE: The iPad case with built-in parental ...
# 143427  1728666794  LIBERTY! EQUALITY! AND FIREWORKS!... A Civil R...
# 227329   225841284  Wooden iPhone case, cradle, & nose for the 4/4...
# 315289   675943042                   Jason Lee Koivula's Solo Project
#
#               category main_category currency    deadline      goal  \
# 113483        Hardware    Technology      USD  2015-10-24   70000.0
# ...

# %% [markdown]
# Next, create a linear interpolation of `usd_pledged_real` as a function of the `backers`. Create a function `f` that generates a linear interpolation of `usd_pledged_real` as predicted by the amount of `backers`.

# %%
# Your code here:
import pandas as pd
from scipy.interpolate import interp1d


sample_df = project.sample(n=10, random_state=42).drop_duplicates(subset=['backers'])

sample_df = sample_df.sort_values(by='backers')

interp_func = interp1d(sample_df['backers'], sample_df['usd_pledged_real'], kind='linear', fill_value='extrapolate')


def f(backers):
    return interp_func(backers)

test_backers = 50
predicted_pledged = f(test_backers)

print(f"For {test_backers} backers, the predicted usd_pledged_real is: {predicted_pledged}")
# Out:
# For 50 backers, the predicted usd_pledged_real is: 2592.3877551020405

# %% [markdown]
# Now create a new variable called `x_new`. This variable will contain all integers between the minimum number of backers in our sample and the maximum number of backers. The goal here is to take the dataset that contains few obeservations due to sampling and fill all observations with a value using the interpolation function.
#
# Hint: one option is the `np.arange` function.

# %%
# Your code here:


min_backers = sample_df['backers'].min()
max_backers = sample_df['backers'].max()

x_new = np.arange(min_backers, max_backers + 1, 1)

predicted_pledged_new = f(x_new)

interpolation_result = pd.DataFrame({'backers': x_new, 'predicted_pledged_real': predicted_pledged_new})

print("Interpolation Result:")
print(interpolation_result)
# Out:
# Interpolation Result:
#     backers  predicted_pledged_real
# 0         0                0.000000
# 1         1               10.000000
# 2         2               31.090000
# 3         3              100.000000
# 4         4              327.666667
# ..      ...                     ...
# 91       91             5929.600000
# 92       92             6136.200000
# 93       93             6342.800000
# 94       94             6549.400000
# 95       95             6756.000000
#
# [96 rows x 2 columns]

# %% [markdown]
# Plot function `f` for all values of `x_new`. Run the code below.

# %%
# Run this code:

# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(x_new, f(x_new))

# %% [markdown]
# Next create a function that will generate a cubic interpolation function. Name the function `g`.

# %%
# Your code here:
from scipy.interpolate import interp1d


sample_df = sample_df.sort_values(by='backers')

interp_func_cubic = interp1d(sample_df['backers'], sample_df['usd_pledged_real'], kind='cubic', fill_value='extrapolate')

def g(backers):
    return interp_func_cubic(backers)

test_backers_cubic = 50
predicted_pledged_cubic = g(test_backers_cubic)
print(f"For {test_backers_cubic} backers, the predicted usd_pledged_real (cubic) is: {predicted_pledged_cubic}")
# Out:
# For 50 backers, the predicted usd_pledged_real (cubic) is: -78.8013593674026

# %%
# Run this code:

plt.plot(x_new, g(x_new))

# %% [markdown]
# # Bonus Challenge - The Binomial Distribution
#
# The binomial distribution allows us to calculate the probability of k successes in n trials for a random variable with two possible outcomes (which we typically label success and failure).
#
# The probability of success is typically denoted by p and the probability of failure is denoted by 1-p.
#
# The `scipy.stats` submodule contains a `binom` function for computing the probabilites of a random variable with the binomial distribution. You may read more about the binomial distribution [here](http://b.link/binomial55)
#
# * In the cell below, compute the probability that a dice lands on 5 exactly 3 times in 8 tries.

# %%
# Your code here:

# %% [markdown]
# * Do a simulation for the last event: do a function that simulate 8 tries and return a 1 if the result is 5 exactly 3 times and 0 if not. Now launch your simulation.

# %%
# Your code here:

# %% [markdown]
# * Launch 10 simulations and represent the result in a bar plot. Now launch 1000 simulations and represent it. What do you see?

# %%
# Your code here:
